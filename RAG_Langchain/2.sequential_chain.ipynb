# %%
#from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
load_dotenv()
# Out:
# True

# %%
prompt1 = PromptTemplate(
    template='Generate a detailed report on {topic}',
    input_variables=['topic']
)

prompt2 = PromptTemplate(
    template='Generate a 5 pointer summary from the following text \n {text}',
    input_variables=['text']
)

# %%
#model = ChatOpenAI()

model = ChatGoogleGenerativeAI(model="gemini-3.6-flash", temperature=0)

parser = StrOutputParser()

# %%
chain = prompt1 | model | parser | prompt2 | model | parser

result = chain.invoke({'topic': 'Bermuda Triangle'})
# Out:
# c:\Users\itpl59\Desktop\ITPL\Projects\python-examples\RAG_Langchain\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3237: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# c:\Users\itpl59\Desktop\ITPL\Projects\python-examples\RAG_Langchain\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3237: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(

# %%
result
# Out:
# '1. The Bermuda Triangle is a region in the North Atlantic Ocean where numerous aircraft and ships have mysteriously disappeared under unexplained circumstances.\n2. Famous incidents attributed to the Bermuda Triangle include the disappearance of Flight 19 in 1945, where five US Navy Avenger bombers vanished during a training flight.\n3. Possible explanations for the incidents in the Bermuda Triangle include compass variations, the Gulf Stream, human error, and methane hydrates.\n4. Despite various conspiracy theories and speculation about supernatural causes, most experts believe the disappearances can be attributed to natural phenomena and human mistakes.\n5. Further research and investigation may help to reveal the true nature of the Bermuda Triangle and dispel some of the myths and misconceptions surrounding it.'
