# %%
#from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableParallel

# %%
load_dotenv()
# Out:
# True

# %%
math_prompt = PromptTemplate.from_template("What is {number} squared?")
fact_prompt = PromptTemplate.from_template("Tell me a fun fact about {number}")

# %%
#model = ChatOpenAI(model="gpt-4o-mini", temperature=0)
model = ChatGoogleGenerativeAI(model="gemini-3.6-flash", temperature=0)

# %%
parser = StrOutputParser()

# %%
math_chain = math_prompt | model | parser
fact_chain = fact_prompt | model | parser

# %%
parallel_chain = RunnableParallel(
    math=math_chain,
    fact=fact_chain
)

# %%
result = parallel_chain.invoke({"number": 7})
print(result)
# Out:
# {'math': '7 squared is 49.', 'fact': 'A fun fact about the number 7 is that it is often considered a "lucky" number in many cultures around the world. For example, in Western culture, people often associate the number 7 with good fortune, as seen in the phrase "lucky number seven." Additionally, there are seven wonders of the ancient world, seven continents, and seven colors in a rainbow, making it a number that frequently appears in various contexts!'}
