# %% [markdown]
# ### Ollama using LangChain

# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="gemma3:4b")

# %%
response = llm.invoke("what is the capital of France?")
print(response.content)
# Out:
# The capital of France is **Paris**.
#
# It’s a global center for art, fashion, gastronomy, and culture! 🇫🇷

# %%
# embedding model
from langchain_ollama import OllamaEmbeddings

embedding_model = OllamaEmbeddings(model="embeddinggemma:latest")

response = embedding_model.embed_query("What is the capital of India?")
print(response)
