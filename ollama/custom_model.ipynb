# %%
import ollama

# %%
import ollama 

response = ollama.generate(model="custom_classification_model:latest", prompt="The product is very bad")
print(response.response)
# Out:
# {\"score\": 0.85, \"label\": "NEGATIVE\"}

# %%
ollama.list()
# ollama.delete(model="custom_classification_model:latest")
# Out:
# ListResponse(models=[Model(model='gemma:latest', modified_at=datetime.datetime(2026, 9, 17, 11, 10, 45, 312681, tzinfo=TzInfo(19800)), digest='a72c7f4d0a15522df81486d13ce432c79e191bda2558d024fbad4362c4f7cbf8', size=5011853225, details=ModelDetails(parent_model='', format='gguf', family='gemma', families=['gemma'], parameter_size='9B', quantization_level='Q4_0')), Model(model='gemma3:4b', modified_at=datetime.datetime(2026, 9, 14, 11, 6, 54, 49825, tzinfo=TzInfo(19800)), digest='a2af6cc3eb7fa8be8504abaf9b04e88f17a119ec3f04a3addf55f92841195f5a', size=3338801804, details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='4.3B', quantization_level='Q4_K_M'))])
